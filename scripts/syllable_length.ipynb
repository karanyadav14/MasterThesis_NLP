# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyconll

# %%
# !pip install stanza
# Out:
# ...
#      |████████████████████████████████| 432 kB 7.0 MB/s
# ...
#      |████████████████████████████████| 175 kB 55.4 MB/s
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=ea0429998ac845edcc272a46bcbb80bbb27c3700bf4b9fee8ce3f6fb405421e4
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

import os
import sys
import csv
import requests
import pyconll
import stanza
from stanza.models.common.doc import Document
from stanza.utils.conll import CoNLL

# %%
filename = 'data.csv'
df = pd.read_csv(filename)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-1e9fa3d01820> in <module>()
#       1 filename = 'data.csv'
# ----> 2 df = pd.read_csv(filename)
#       3 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
ascii_for_extras = ['े', '्', 'h','ँ', 'ं','\\', 'ः','ऺ','ऻ','़','ा','ि','ी','ु','ू','ृ','ॄ','ॅ','ॆ','ै','ॉ','ॊ','ो','ौ','ॎ','ॏ','ॕ','ॢ','ॣ']

def count_syllable(word):
    count = 0
    for char in word:
    # print(char)
        if char not in ascii_for_extras:
      # print(char)
            count += 1
      
    return count



#giving the path of the directory
path = "/content/drive/MyDrive/HD Corpus/Files/Output_files/"
dirs = os.listdir(path)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("hi_1385_output.txt"):
        filename_in = filename
    
        
        file = pyconll.load_from_file(filename_in)

        
        #Unigram Frequency
#         f_dict = Counter()
        
        for sentence in file:
            sent = (sentence.meta_value("Sentence")).split(" ")
            print(sent)
            
            for word in sent:
                abc = count_syllable(word)
                print(abc)
# Out:
# ['ओए', 'तुम', 'सुन', 'रहे', 'थे', 'ना', '।']
# 2
# 2
# 2
# 2
# 1
# 1
# 1
# ['हाँ', 'सुन', 'रहा', 'था', '।']
# 1
# 2
# 2
# 1
# 1
# ['अब', 'क्या', 'अपना', 'सब', 'रिकॉर्ड', 'हो', 'के', 'हर', 'जगह', 'जाएगा', 'क्या', '[laughter]', '।']
# 2
# 2
# 3
# 2
# 4
# 1
# 1
# 2
# 3
# 3
# 2
# 9
# 1
# ['ठीक', 'है', '।']
# 2
# 1
# 1
# ['सीएनएन', 'न्यूज़', 'में', 'आ', 'जाएँगे', 'हम', 'लोग', '।']
# 5
# 3
# 1
# 1
# 3
# 2
# 2
# 1
# ['[laughter]', 'यश', 'के', 'बारे', 'में', 'बात', 'करो', '।']
# 9
# 2
# 1
# 2
# 1
# 2
# 2
# 1
# ['हाँ', '।']
# 1
# 1
# ['[laughter]', 'पब्लिक', 'इन्फ़र्मेशन', 'बनेगा', '।']
# 9
# 4
# 7
# 3
# 1
# ['सो_आइ_गेस_दैट_दैट्स_बैड_न्यूज़', '।']
# 21
# 1
# ['हाँ', 'सीएनएन', 'में', '[anonymized]', '।']
# 1
# 5
# 1
# 12
# 1
# ['[anonymized]_टॉकिंग_अबाउट_क्यूट_चिक्स', '।']
# 29
# 1
# ['[laughter]', '।']
# 9
# 1
# ['नो', '।']
# 1
# 1
# ['तो', 'एनीवे', '।']
# 1
# 3
# 1
# ...

# %%
ascii_for_extras = ['े', '्', 'h','ँ', 'ं','\\', 'ः','ऺ','ऻ','़','ा','ि','ी','ु','ू','ृ','ॄ','ॅ','ॆ','ै','ॉ','ॊ','ो','ौ','ॎ','ॏ','ॕ','ॢ','ॣ','r','s']

def count_syllable(word):
  count = 0
  for char in word:
    # print(char)
    if char not in ascii_for_extras:
      # print(char)
      count += 1
      
    return count



df['Syllable Length'] = df['Word'].apply(count_syllable)
df
