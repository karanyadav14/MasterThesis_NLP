# %% [markdown]
# ## Step1: Checks

# %%
#this script checks the .format file for the follwing errors:
# double white space
# check for pipe symbol instaed of hindi purnaviram symbol and undo if found
# pairing of annotation tags- even number of instances in each utterance - if not, print the error with filename, begin_time, utterance
# the overlap tag should be equal in number for Sp1 and Sp2 - print the no. of # for Sp1 and Sp2


import os
import csv

#giving the path of the directory
path ="E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/Scripts_Ind/"
dirs = os.listdir(path)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_0.csv"):
        filename_in = filename
        filename_out = filename_in.replace("_0.csv", "_1_checks_new.txt")
        #print ("in = "+ filename_in)
        #print ("out = "+ filename_out)

        fields = []
        rows = []
        column_value = "" #variable for the string in the transcription column
        data_value= "" #variable for the string in the transcription column as it will appear in the output file
        speaker_value = "" #variable for th string value of Speaker1 or Speaker2
        result_list = []

        count_overlap_sp1 = 0
        count_overlap_sp2 = 0

        with open(filename_in, 'r', encoding="utf-8") as csvfile:
            csvreader = csv.reader(csvfile)
            reader = csv.DictReader(csvfile, delimiter=",")
            #print (filename_in)
            
            for row in reader:
                
                begin_time = row["Begin Time - hh:mm:ss.ms"]
                end_time = row["End Time - hh:mm:ss.ms"]
                duration = row["Duration - hh:mm:ss.ms"]
                speaker_1 = row["Channel1"]
                speaker_2 = row["Channel2"]
            
                
                # the last above line assigns str in "data" column to variable data_value. 
                # Also replaces a double white space with a single white space 
                # Replaces pipe symbol with hindi purnaviram symbol
                if speaker_1 !="":
                    data_value=speaker_1;
                else:
                    data_value=speaker_2;
                
                data_value = str(data_value).replace("  "," ").replace("|","।")
                #count the number of \d in the utterance and print (filename+begin_time_utterance) if odd number of occurances
                count_d = int(data_value.count(r"\d"))
                if (count_d % 2) != 0:   
                    print ("ERROR FOR d: " + filename_in[-16:-9] + " " + begin_time + " " + data_value)

                #count the number of \r in the utterance and print (filename+begin_time_utterance) if odd number of occurances
                count_r = int(data_value.count(r"\r"))
                if (count_r % 2) != 0:   
                    print ("ERROR FOR r: " + filename_in[-16:-9] + " " + begin_time + " " + data_value)

                #count the number of \h in the utterance and print (filename+begin_time_utterance) if odd number of occurances
                count_h = int(data_value.count(r"\h"))
                if (count_h % 2) != 0:   
                    print ("ERROR FOR h: " + filename_in[-16:-9] + " " + begin_time + " " + data_value)

                #count the number of \exp in the utterance and print (filename+begin_time_utterance) if odd number of occurances
                count_exp = int(data_value.count(r"\exp"))
                if (count_exp % 2) != 0:   
                    print ("ERROR FOR exp: " + filename_in[-16:-9] + " " + begin_time + " " + data_value)

                #count the number of \q in the utterance and print (filename+begin_time_utterance) if odd number of occurances
                count_q = int(data_value.count(r"\q"))
                if (count_q % 2) != 0:   
                    print ("ERROR FOR q: " + filename_in[-16:-9] + " " + begin_time + " " + data_value)

                #count the number of \c in the utterance and print (filename+begin_time_utterance) if odd number of occurances
                count_c = int(data_value.count(r"\c"))
                if (count_c % 2) != 0:   
                    print ("ERROR FOR c: " + filename_in[-16:-9] + " " + begin_time + " " + data_value)

                #count the number of # in the utterance and print (filename+begin_time_utterance) if odd number of occurances
                count_overlap = int(data_value.count(r"#"))
                if (count_overlap % 2) != 0:   
                    print ("ERROR FOR overlap: " + filename_in[-16:-9] + " " + begin_time + " " + data_value)

                #to check overlaps - additional check - for the 2 speakers, the total number of overlap tags should be the same
                if speaker_1 != "":
                    count_overlap_sp1 = count_overlap_sp1 + count_overlap
                if speaker_2 != "":
                    count_overlap_sp2 = count_overlap_sp2 + count_overlap
                
                if speaker_1 !="":
                    speaker_1=data_value;
                else:
                    speaker_2=data_value;
                    
                result_list.append([begin_time, end_time, duration, speaker_1, speaker_2])
                #print(result_list)

        #the following prints for each file, the total number of overlap tags for Sp1 and Sp2 
        print (str(filename_in[-20:-13]) + " Sp1 overlap count is " + str(int(count_overlap_sp1)))
        print (str(filename_in[-20:-13]) + " Sp2 overlap count is " + str(int(count_overlap_sp2)))

            # writing to csv file
        with open(filename_out, 'w',encoding="utf-8", newline='') as csvfile:
            # creating a csv writer object
            csvwriter = csv.writer(csvfile)
            # writing the fields
            fields = ["Begin Time - hh:mm:ss.ms","End Time - hh:mm:ss.ms","Duration - hh:mm:ss.ms", 'Channel1','Channel2']
            csvwriter.writerow(fields)
            csvwriter.writerows(result_list)
# Out:
# ts_Ind/ Sp1 overlap count is 178
# ts_Ind/ Sp2 overlap count is 174
# ERROR FOR overlap: nd/hi_4 00:00:02.626 [laughter] यार अब तो बकवास ही करना है । [laughter] # नहीं यहाँ पे मस्त रहते है । ऐसे ही हम लोग क्या किया
# ts_Ind/ Sp1 overlap count is 133
# ts_Ind/ Sp2 overlap count is 136
# ts_Ind/ Sp1 overlap count is 94
# ts_Ind/ Sp2 overlap count is 110
# ERROR FOR d: nd/hi_6 00:12:03.931 नहीं मतलब क्या ये \r 1 साल से \d 1 साल से बंद ही है क्या
# ERROR FOR r: nd/hi_6 00:12:03.931 नहीं मतलब क्या ये \r 1 साल से \d 1 साल से बंद ही है क्या
# ts_Ind/ Sp1 overlap count is 194
# ts_Ind/ Sp2 overlap count is 190
# ts_Ind/ Sp1 overlap count is 146
# ts_Ind/ Sp2 overlap count is 142
# ERROR FOR overlap: nd/hi_6 00:08:21.849 # ठीक है # वो उस का # हस्बेंड अगर चाहता है जैसे रखना चाहता है वैसे रहे तो ठीक है । # मतलब कम से कम # \r उस का \r # माँ की आदत # वादत छोड़ी है मतलब छूट ही जाता है शादी के बाद
# ERROR FOR overlap: nd/hi_6 00:16:10.331 हाँ । \r नहीं \r अब मतलब वहाँ ही रहना ही है । # मकान तुम्हारा है ही । तो # तुम्हें मतलब वहाँ का ले के ही रहना चाहिए #
# ERROR FOR overlap: nd/hi_6 00:18:35.653 कि नहीं । अब \r 10 1 द \r 1 हफ़्ते इस इंटर्व्यू के लिए इंतज़ार करना है । 1 हफ़्ते अगले के लिए इंतज़ार करना है । # [laughter] फ़िर अगल
# ERROR FOR overlap: nd/hi_6 00:23:08.956 # यहाँ पे # ये बच्चे हैं ना । तो इन लोगों से ही तुम मतलब # पता कर सकती हो ना कि हम लोग हैं कहाँ
# ERROR FOR r: nd/hi_6 00:25:30.307 \r तुम क्या कह रही \r तुम ने कार्ड \r तुम्हारा आया तो है कार्ड मेरे पास
# ts_Ind/ Sp1 overlap count is 388
# ts_Ind/ Sp2 overlap count is 372
# ts_Ind/ Sp1 overlap count is 206
# ts_Ind/ Sp2 overlap count is 194
# ERROR FOR c: nd/hi_6 00:18:14.041 \d तमिल \d तमिल \r \c आइ थिंक श्रीलंका आइ थिंक दे \c \r \d तमिलीयन \d तमिलीयन \c बोलते हैं ना
# ts_Ind/ Sp1 overlap count is 170
# ts_Ind/ Sp2 overlap count is 172

# %% [markdown]
# ## Step2: Format

# %%
# formats the ELAN output to add Speaker_id (Sp1 and Sp2)
# merges two Channel columns (for two speakers) to one data column
# adds purna viram to the end of every utterance
#   Input file = hi_1234_0.txt  
#   Output file =  hi_1234_1_format.txt

import os, sys
import csv


#giving the path of the directory
path = "E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/Scripts_Ind/"
dirs = os.listdir(path)
print(dirs)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_1_checks_new.txt"):
        filename_in = filename
        filename_out = filename_in.replace("_1_checks_new.txt","_2_format_new.txt")
        #print ("in = "+ filename_in)
        #print ("out = "+ filename_out)

        fields = []
        rows = []
        column_value = "" #variable for the string in the transcription column
        data_value= "" #variable for the string in the transcription column as it will appear in the output file
        speaker_value = "" #variable for th string value of Speaker1 or Speaker2
        result_list = []  
        
        with open(filename_in, 'r', encoding="utf-8") as csvfile:
            csvreader = csv.reader(csvfile)
            reader = csv.DictReader(csvfile, delimiter=",")
            #print (filename_in)
            flag=False
            flag1=False
            for row in reader:
                
                begin_time = row["Begin Time - hh:mm:ss.ms"]
                end_time = row["End Time - hh:mm:ss.ms"]
                duration = row["Duration - hh:mm:ss.ms"]
                speaker_1 = row["Channel1"]
                speaker_2 = row["Channel2"]
                
                #print(speaker_1, len(speaker_1), "-", speaker_2, len(speaker_2))
                if len(str(speaker_1).strip()) == 0:    # use strip in case there are empty spaces at the end of the string
                    column_value = str(speaker_2).strip()    #if empty then this col will be filled with speaker2 value 
                    if "[b_speaker3]" in (column_value):
                        flag=True
                        speaker_value="Sp3"
                   
                    elif "[e_speaker3]" in (column_value) :
                        flag=False
                        speaker_value="Sp3"
                        
                    elif flag==True:
                        speaker_value="Sp3"
                    else:
                        speaker_value = "Sp2"       # correct speaker id is inserted
                if len(str(speaker_2).strip()) == 0:
                    column_value = str(speaker_1).strip()
                    if "[b_speaker3]" in (column_value):
                        flag1=True
                        speaker_value="Sp3"
                    elif flag1==True:
                        speaker_value="Sp3"
                    elif "[e_speaker3]" in (column_value) :
                        flag1=False
                        speaker_value="Sp3"   
                    else:
                        speaker_value = "Sp1" 
                data_value = column_value+str(" ।")     #add a period marker at the end of every utterance
                #This last above step can be omitted if the sentence segmentation is taken care of in the transcription
                result_list.append([begin_time, end_time, duration, speaker_value, data_value])
                #print(result_list)
    
        # writing to csv file
        with open(filename_out, 'w',encoding="utf-8", newline='') as csvfile:
        # creating a csv writer object
            csvwriter = csv.writer(csvfile)
        # writing the fields
            fields = ['Begin_Time-hh:mm:ss.ms', 'End_Time-hh:mm:ss.ms', 'Duration-hh:mm:ss.ms', 'speaker_id', 'data']
            csvwriter.writerow(fields)
            csvwriter.writerows(result_list)
# Out:
# ['hi_1385_0.csv', 'hi_1385_1_checks_new.txt', 'hi_1385_2_format_new.txt', 'hi_1385_3_segments_new.txt', 'hi_1385_4_chunks_new.txt', 'hi_1385_5_misc_new.txt', 'hi_1385_6_udpos_new.txt', 'hi_1385_7_udpos_rules_new.txt', 'hi_1385_8_udpos_parse_new.txt', 'hi_4370_0.csv', 'hi_4370_1_checks_new.txt', 'hi_4370_2_format_new.txt', 'hi_4370_3_segments_new.txt', 'hi_4370_4_chunks_new.txt', 'hi_4370_5_misc_new.txt', 'hi_4370_6_udpos_new.txt', 'hi_4370_7_udpos_rules_new.txt', 'hi_4370_8_udpos_parse_new.txt', 'hi_6322_0.csv', 'hi_6322_1_checks_new.txt', 'hi_6322_2_format_new.txt', 'hi_6322_3_segments_new.txt', 'hi_6322_4_chunks_new.txt', 'hi_6322_5_misc_new.txt', 'hi_6322_6_udpos_new.txt', 'hi_6322_7_udpos_rules_new.txt', 'hi_6322_8_udpos_parse_new.txt', 'hi_6435_0.csv', 'hi_6435_1_checks_new.txt', 'hi_6435_2_format_new.txt', 'hi_6435_3_segments_new.txt', 'hi_6435_4_chunks_new.txt', 'hi_6435_5_misc_new.txt', 'hi_6435_6_udpos_new.txt', 'hi_6435_7_udpos_rules_new.txt', 'hi_6435_8_udpos_parse_new.txt', 'hi_6441_0.csv', 'hi_6441_1_checks_new.txt', 'hi_6441_2_format_new.txt', 'hi_6441_3_segments_new.txt', 'hi_6441_4_chunks_new.txt', 'hi_6441_5_misc_new.txt', 'hi_6441_6_udpos_new.txt', 'hi_6441_7_udpos_rules_new.txt', 'hi_6441_8_udpos_parse_new.txt', 'hi_6523_0.csv', 'hi_6523_1_checks_new.txt', 'hi_6523_2_format_new.txt', 'hi_6523_3_segments_new.txt', 'hi_6523_4_chunks_new.txt', 'hi_6523_5_misc_new.txt', 'hi_6523_6_udpos_new.txt', 'hi_6523_7_udpos_rules_new.txt', 'hi_6523_8_udpos_parse_new.txt', 'hi_6579_0.csv', 'hi_6579_1_checks_new.txt', 'hi_6579_2_format_new.txt', 'hi_6579_3_segments_new.txt', 'hi_6579_4_chunks_new.txt', 'hi_6579_5_misc_new.txt', 'hi_6579_6_udpos_new.txt', 'hi_6579_7_udpos_rules_new.txt', 'hi_6579_8_udpos_parse_new.txt', 'hi_6585_0.csv', 'hi_6585_1_checks_new.txt', 'hi_6585_2_format_new.txt', 'hi_6585_3_segments_new.txt', 'hi_6585_4_chunks_new.txt', 'hi_6585_5_misc_new.txt', 'hi_6585_6_udpos_new.txt', 'hi_6585_7_udpos_rules_new.txt', 'hi_6585_8_udpos_parse_new.txt']

# %% [markdown]
# ## Step 3: Segments

# %%
# one word in a row with space as a delimiter (including annotation tags)
# each token/word given an index
# sentence segmentation with purnaviram as delimiter
# sent_id added to each sentence
# Metadata added as comments before every sentence: begin_time, end_time, duration, speaker_id, contains_overlap
# contains_overlap = True/False (removes # from tokens)
# insert blank row after every sentence (after every PUNCT)

import os, sys
import csv

#giving the path of the directory
path = "E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/Scripts_Ind/"
dirs = os.listdir(path)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_2_format_new.txt"):
        filename_in = filename
        filename_out = filename_in.replace("_2_format_new.txt", "_3_segments_new.txt")
        #print ("in = "+ filename_in)
        #print ("out = "+ filename_out)

        fields = []
        rows = []
        result_list = []
        sent_id = 1

        with open(filename_in, 'r',encoding="utf-8") as csvfile:
            csvreader = csv.reader(csvfile)
            reader = csv.DictReader(csvfile, delimiter=',')
            
            result_list.append([("# sent_id = " + str(sent_id)),""])

            for row in reader:
                word_index = 1
                file_name= filename_in[-16:-9]
                begin_time = row["Begin_Time-hh:mm:ss.ms"]
                end_time = row["End_Time-hh:mm:ss.ms"]
                duration = row["Duration-hh:mm:ss.ms"]
                speaker_name = row["speaker_id"]
                rowdata = str(row['data']).strip()
                word_list = rowdata.split(' ')
                overlap_value = rowdata.find("#")
                if overlap_value == -1:
                    ol = "False"
                else: 
                    ol = "True"

                #print(word_list)

                result_list.append([("# begin_time = " + str(begin_time)), ""])
                result_list.append([("# end_time = " + str(end_time)), ""])
                result_list.append([("# duration = " + str(duration)), ""])
                result_list.append([("# speaker_id = " + str(speaker_name)), ""])
                result_list.append([("# contains_overlap = "+ol), ""])
                
                i = 0
                N = len(word_list)

                for word in word_list:
                    i = i + 1
                
                    #if word != "": #this line creates a check for double spaces - not required now, as double speces eliminated by checks.py
                    if word == "#":
                        continue
                    
                    if word == "।" and i < N:
                        result_list.append([word_index, word])
                        result_list.append(["", ""])
                        
                        word_index = 1
                        sent_id = sent_id+1        
                        result_list.append([("# sent_id = " + str(sent_id)),""])
                    
                        result_list.append([("# begin_time = " + str(begin_time)),""])
                        result_list.append([("# end_time = " + str(end_time)),""])
                        result_list.append([("# duration = " + str(duration)),""])
                        result_list.append([("# speaker_id = " + str(speaker_name)),""])
                        result_list.append([("# contains_overlap = "+ol), ""])
                    elif word == "।":
                        result_list.append([word_index, word])
                        result_list.append(["", ""])
                        
                        word_index = 1
                        sent_id = sent_id+1        
                        result_list.append([("# sent_id = " + str(sent_id)),""])
                    else:
                        result_list.append([word_index, word])
                        word_index = word_index+1
                                

        with open(filename_out, 'w',encoding="utf-8", newline='') as csvfile:
            # creating a csv writer object
            csvwriter = csv.writer(csvfile, delimiter = '\t')
            csvwriter.writerows(result_list)

# %% [markdown]
# ## Step 4: Chunks

# %%
#4_CHUNKS.PY

# creates chunks based on (outermost) annotation tags 
# re-orders the word indices within sentences after chunking
# adds prefix and suffix of outermost tag to the chunk 
# creates a misc string for outermost tag
# nested tags are included in the chunk as is
# maintain the structure of metadta in comments 

import os
import csv 

#giving the path of the directory
path = "E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/Scripts_Ind/"
dirs = os.listdir(path)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_3_segments_new.txt"):
        filename_in = filename
        filename_out = filename_in.replace("_3_segments_new.txt", "_4_chunks_new.txt")
        #print ("in = "+ filename_in)
        #print ("out = "+ filename_out)

        result_list= []
        sent_id = 1
        chunk_list = []
        chunk = ""
        chunk_id = ""
        word_index = 1
        misc = {}
        with open(filename_in,'r', encoding = 'utf-8') as csvfile:
            csvreader = csv.reader(csvfile, delimiter='\t')

            for row in csvreader:  
                word_n = row[0]
                #print(word_n)
                word_form = row[1]
                #print(word_form)
                #print(type(word_form))
                if len(chunk_list) != 0 and word_form[0]!="\\":
                    chunk_list.append(word_form)

                if word_n.startswith("#"):
                    result_list.append([word_n,"","","","","","","","",""])
                    continue
                elif word_n == "":
                    continue 
                elif word_form =="।":
                    if len(chunk_list) != 0:
                        chunk_list.append(chunk_id)
                        chunk = "_".join(chunk_list)
                        #chunk = chunk.replace("\\","")
                        result_list.append([str(word_index),chunk,misc])
                        word_index = word_index + 1
                        result_list.append([str(word_index),word_form,"_"])
                        result_list.append(["","",""])
                        word_index = 1
                        chunk_list =[]  
                        #this block should check instances of errors where tag is not closed. This code should serve as a barrier for the error to carry over beyond sentence boundary.
                        #check in the end if this block works, by manually removing one of the closing tags (outermost, not nested) in a sentence
                    else:
                        result_list.append([str(word_index),word_form,"_"])
                        result_list.append(["","",""])
                        word_index = 1  

                elif word_form.startswith("\\"):
                    if len(chunk_list) == 0:
                        chunk_id = word_form
                        chunk_list.append(word_form)
                        
                        if word_form[1]=='q':
                            misc = "Quote=Matrix_Tag"
                        if word_form[1]=='c': 
                            misc = "CodeSwitch=Matrix_Tag"
                        if word_form[1]=='r':
                            misc = "Repair=Matrix_Tag"
                        if word_form[1]=='d':
                            misc = "Disfluency=Matrix_Tag"
                        if word_form[1]=='h':
                            misc = "Hesitation=Matrix_Tag"
                        if word_form[1]=='exp':  
                            misc = "Expletive=Matrix_Tag"
                        
                        print(misc)
                    elif word_form == chunk_id:
                        chunk_list.append(word_form)
                        chunk = "_".join(chunk_list)
                        #chunk = chunk.replace("\\","")
                        result_list.append([str(word_index),chunk,misc])
                        word_index = word_index +1
                        chunk_list =[]
                    else:
                        chunk_list.append(word_form)
                    continue                            
                    
                else:
                    if len(chunk_list) == 0:
                        result_list.append([str(word_index) ,word_form,"_"])
                        word_index = word_index + 1
                    
        with open(filename_out, 'w',encoding = 'utf-8', newline='') as csvfile:
            csvwriter = csv.writer(csvfile, delimiter = '\t')
            csvwriter.writerows(result_list)
# Out:
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Quote=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Quote=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Repair=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Quote=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Quote=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Disfluency=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Repair=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# Hesitation=Matrix_Tag
# Hesitation=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag
# CodeSwitch=Matrix_Tag

# %% [markdown]
# ## Step 5: Misc

# %%
# maintains the sent_id and word_index of the tokens
# for each nested tag, adds information to misc column
# removes tags from the chunks
# format of chunk: prefix & suffix "_" retained (is this needed?)
# formats the output to conllu format 
# maintains the structure of metadata in comments

import os
import csv

#giving the path of the directory
path = "E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/Scripts_Ind/"
dirs = os.listdir(path)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_4_chunks_new.txt"):
        filename_in = filename
        filename_out = filename_in.replace("_4_chunks_new.txt", "_5_misc_new.txt")
        #print ("in = "+ filename_in)
        #print ("out = "+ filename_out)
        
        
        with open(filename_in,'r', encoding = 'utf-8') as csvfile:
            csvreader = csv.reader(csvfile, delimiter='\t' )
            
            result_list = []
            
            for row in csvreader:
                #print(row)
                word_n = row[0]
                #print(word_n)
                word_form = row[1]
                #print(word_form)
                misc = row[2]
                #print(misc)
                misc_list= []

                if word_n.startswith("#"):
                    result_list.append(word_n+'\n')
                    continue

                elif word_n =="":
                    result_list.append('\n')  
                    continue
                
                elif word_form.startswith("\\"):
                    misc_list.append(misc)
                    #print(misc)
                    if "_\\q_" in word_form or "_\\r_" in word_form or "_\\d_" in word_form or "_\\h_" in word_form or "_\\c_" in word_form or "_\\exp_" in word_form:
                        misc_list.append("NestedTag=True")
                        #misc_list.append({"NestedTag":"True"})
                        if "_\\q_" in word_form:
                            subtag = word_form.split("\\q")[1].strip("_")
                            misc_list.append("Quote='"+subtag+"'")
                            #print (subtag)
                        if "_\\r_" in word_form:
                            subtag = word_form.split("\\r")[1].strip("_")
                            misc_list.append("Repair='"+subtag+"'")
                            #print (subtag)
                        if "_\\d_" in word_form:
                            subtag = word_form.split("\\d")[1].strip("_")
                            misc_list.append("Disfluency='"+subtag+"'")
                            #print (subtag)
                        if "_\\h_" in word_form:
                            subtag = word_form.split("\\h")[1].strip("_")
                            misc_list.append("Hesitation='"+subtag+"'")
                            #print (subtag)
                        if "_\\c_" in word_form:
                            subtag = word_form.split("\\c")[1].strip("_")
                            misc_list.append("CodeSwitch='"+subtag+"'")
                            #print (subtag)
                        if "_\\exp_" in word_form:
                            subtag = word_form.split("\\exp")[1].strip("_")
                            misc_list.append("Expletive='"+subtag+"'")
                            #print (subtag)   
                        misc = r"|".join(misc_list) 
                        #print (type(misc))
                        #print(misc_list)
                        print(misc)
                        word_form = word_form.replace("\\q_", "")
                        word_form = word_form.replace("_\\q", "")
                        word_form = word_form.replace("\\r_", "")
                        word_form = word_form.replace("_\\r", "")
                        word_form = word_form.replace("\\d_", "")
                        word_form = word_form.replace("_\\d", "")
                        word_form = word_form.replace("\\h_", "")
                        word_form = word_form.replace("_\\h", "")
                        word_form = word_form.replace("\\c_", "")
                        word_form = word_form.replace("_\\c", "")
                        word_form = word_form.replace("\\exp_", "")
                        word_form = word_form.replace("_\\exp", "")
                        word_form = word_form.replace("__", "_")
                        
                        result_list.append(word_n+'\t'+word_form+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+misc+'\n')
                    else:
                        word_form = word_form.replace("\\q_", "")
                        word_form = word_form.replace("_\\q", "")
                        word_form = word_form.replace("\\r_", "")
                        word_form = word_form.replace("_\\r", "")
                        word_form = word_form.replace("\\d_", "")
                        word_form = word_form.replace("_\\d", "")
                        word_form = word_form.replace("\\h_", "")
                        word_form = word_form.replace("_\\h", "")
                        word_form = word_form.replace("\\c_", "")
                        word_form = word_form.replace("_\\c", "")
                        word_form = word_form.replace("\\exp_", "")
                        word_form = word_form.replace("_\\exp", "")
                        word_form = word_form.replace("__", "_")
                        
                        result_list.append(word_n+'\t'+word_form+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+misc+'\n')    
                else:
                    result_list.append(word_n+'\t'+word_form+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\t'+"_"+'\n')
                
                          
        with open(filename_out, 'w', encoding = 'utf-8') as f:
                for item in result_list:
                    f.write(item)
# Out:
# CodeSwitch=Matrix_Tag|NestedTag=True|Disfluency='दैट'
# Repair=Matrix_Tag|NestedTag=True|Hesitation='अ'|CodeSwitch='आइ_मीन'
# Repair=Matrix_Tag|NestedTag=True|CodeSwitch='हील'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='एसिक्स_लाइब्रेरी'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='हाउ_मेनी'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='आइ'|Hesitation='म'
# CodeSwitch=Matrix_Tag|NestedTag=True|Hesitation='अह'
# CodeSwitch=Matrix_Tag|NestedTag=True|Disfluency='यौर'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='आइ_डोंट'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='आइ_मीन_शीस'|Hesitation='अम'
# Repair=Matrix_Tag|NestedTag=True|Hesitation='अह'|CodeSwitch='ओह_आइम_श्योर_ही_वुड_गो_टू_बॉस्टन_ऑल्सो_ड्राइविंग'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='एमएस_और_पीएचडी'|Hesitation='अम'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='ऐज़'
# Repair=Matrix_Tag|NestedTag=True|Hesitation='अम'
# CodeSwitch=Matrix_Tag|NestedTag=True|Disfluency='अभी'
# Repair=Matrix_Tag|NestedTag=True|CodeSwitch='ऐंड_रंजन'
# Repair=Matrix_Tag|NestedTag=True|Disfluency='1_साल_से_बंद_ही_है_क्या_।_\r'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='वासुदेव_सुतं_देवम'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='वासुदेव_सुतं_देवं_कंस_चाणूर_मर्दनम्_।_\q'
# CodeSwitch=Matrix_Tag|NestedTag=True|Quote='।_\c'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='कंस_चाणूर_मर्दनम्_।_\q'
# CodeSwitch=Matrix_Tag|NestedTag=True|Quote='।_\c'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='वन्दे_जगद्गुरुम्'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='धर्मक्षेत्रे_कुरुक्षेत्रे'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='कुरुक्षेत्रे'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='समवेता_युयुत्सवः।_मामकाः_पाण्डवाश्चैव_किमकुर्वत_सञ्जय:'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='धर्मक्षेत्रे_कुरुक्षेत्रे_समवेता_युयुत्सवः।_मामकाः_पाण्डवाश्चैव'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='मामकाः_पाण्डवाश्चैव_किमकुर्वत_सञ्जय:'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='ॐ_शांताकारं_भुजगशयनं_पद्मनाभं_सुरेशम्_श्री_विश्वाधारं_गगनसदृशं_मेघवर्णं_शुभाङ्गम्'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='लक्ष्मीकान्तं'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='लक्ष्मीकान्तं_कमलनयनं_योगिभिर्ध्यानगम्यम्_वन्दे_विष्णुं_भवभयहरं_सर्वलोकैकनाथम्'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='योगिभिर्ध्यानगम्यम्_वन्दे_विष्णुं'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='सर्वलोकैकनाथम्'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='त्वमेव_माता'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='माता_च_पिता_त्वमेव_।_\q'
# CodeSwitch=Matrix_Tag|NestedTag=True|Quote='।_\c'
# Quote=Matrix_Tag|NestedTag=True|Repair='त्वमेव_माता'|CodeSwitch='\r_त्वमेव_माता_\r_त्वमेव_माता_च_पिता_त्वमेव'
# Quote=Matrix_Tag|NestedTag=True|Repair='बंदा'|CodeSwitch='त्वमेव_\r_बंदा_\r_बंधुश्च_सखा_त्वमेव'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='त्वमेव_विद्या_च_द्रविड़म_त्वमेव'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='त्वमेव_सर्वम्_मम्_देव_देवा'
# Quote=Matrix_Tag|NestedTag=True|CodeSwitch='मम्_देव_देवा'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='किसी_के_सामने'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='लीव'
# CodeSwitch=Matrix_Tag|NestedTag=True|Hesitation='अ'
# Repair=Matrix_Tag|NestedTag=True|CodeSwitch='बट'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='उसका_तो_कोई'
# Repair=Matrix_Tag|NestedTag=True|CodeSwitch='इट्स_अ'
# CodeSwitch=Matrix_Tag|NestedTag=True|Hesitation='अ'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='द'
# CodeSwitch=Matrix_Tag|NestedTag=True|Hesitation='अम'
# Repair=Matrix_Tag|NestedTag=True|CodeSwitch='इट्स'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='वी'
# CodeSwitch=Matrix_Tag|NestedTag=True|Disfluency='ईवन'
# CodeSwitch=Matrix_Tag|NestedTag=True|Hesitation='अह'
# Repair=Matrix_Tag|NestedTag=True|CodeSwitch='ऐंड_दे_आर'
# CodeSwitch=Matrix_Tag|NestedTag=True|Hesitation='अह'
# CodeSwitch=Matrix_Tag|NestedTag=True|Disfluency='स'
# CodeSwitch=Matrix_Tag|NestedTag=True|Disfluency='दे'
# Repair=Matrix_Tag|NestedTag=True|CodeSwitch='ही_मस्ट_बी'
# CodeSwitch=Matrix_Tag|NestedTag=True|Disfluency='दैट्स'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='जेनरली'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='एक्चुअली_द'
# CodeSwitch=Matrix_Tag|NestedTag=True|Hesitation='अह'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='देर_इज़_अ'|Disfluency='द'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='दिस'|Hesitation='अह'
# CodeSwitch=Matrix_Tag|NestedTag=True|Hesitation='अह'
# Repair=Matrix_Tag|NestedTag=True|Hesitation='अह'
# Repair=Matrix_Tag|NestedTag=True|Hesitation='अह'|CodeSwitch='ऐंड_मिरर_इफ़_यू_\h_अह_\h'
# CodeSwitch=Matrix_Tag|NestedTag=True|Hesitation='अह'
# Repair=Matrix_Tag|NestedTag=True|CodeSwitch='आइ_थिंक_श्रीलंका_आइ_थिंक_दे'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='देन_देर'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='लॉ'
# CodeSwitch=Matrix_Tag|NestedTag=True|Disfluency='इन'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='ये'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='याह_बेसिक्ली_दे'|Hesitation='अह'
# Repair=Matrix_Tag|NestedTag=True|Disfluency='1'
# Repair=Matrix_Tag|NestedTag=True|CodeSwitch='ऐंड_आइ_थिंक'
# CodeSwitch=Matrix_Tag|NestedTag=True|Repair='उन_को'

# %% [markdown]
# ### Stanza

# %%
import stanza
from stanza.models.common.doc import Document
from stanza.utils.conll import CoNLL


import requests
import os
#url = "http://lindat.mff.cuni.cz/services/udpipe/api/process"

#giving the path of the directory
path = "E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/"
dirs = os.listdir(path)
#print(dirs)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_5_misc_new.txt"):
        filename_in = filename
        #filename_out = filename_in.replace("_7_udpos_rules_Stanza.txt", "_8_udpos_parse_Stanza.txt")
        doc = CoNLL.conll2doc(filename)
        
        nlp = stanza.Pipeline(lang='hi', processors='tokenize,pos,mwt')
        doc1 = nlp(doc)
        print(doc1)
        CoNLL.write_doc2conll(doc1, "output_Upos.conllu")
# Out:
# 2021-09-13 17:41:54 INFO: Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | mwt       | default |
# | pos       | hdtb    |
# =======================
#
# 2021-09-13 17:41:54 INFO: Use device: cpu
# 2021-09-13 17:41:54 INFO: Loading: tokenize
# 2021-09-13 17:41:54 INFO: Loading: mwt
# 2021-09-13 17:41:54 ERROR: Cannot load model from C:\Users\karan\stanza_resources\hi\mwt\default.pt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\stanza\pipeline\core.py in __init__(self, lang, dir, package, processors, logging_level, verbose, use_gpu, model_dir, **kwargs)
#     135                 # try to build processor, throw an exception if there is a requirements issue
# --> 136                 self.processors[processor_name] = NAME_TO_PROCESSOR_CLASS[processor_name](config=curr_processor_config,
#     137                                                                                           pipeline=self,
#
# C:\ProgramData\Anaconda3\lib\site-packages\stanza\pipeline\processor.py in __init__(self, config, pipeline, use_gpu)
#     158         if not hasattr(self, '_variant'):
# --> 159             self._set_up_model(config, use_gpu)
#     160
#
# C:\ProgramData\Anaconda3\lib\site-packages\stanza\pipeline\mwt_processor.py in _set_up_model(self, config, use_gpu)
#      20     def _set_up_model(self, config, use_gpu):
# ---> 21         self._trainer = Trainer(model_file=config['model_path'], use_cuda=use_gpu)
#      22
#
# C:\ProgramData\Anaconda3\lib\site-packages\stanza\models\mwt\trainer.py in __init__(self, args, vocab, emb_matrix, model_file, use_cuda)
#      35             # load from file
# ---> 36             self.load(model_file, use_cuda)
#      37         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\stanza\models\mwt\trainer.py in load(self, filename, use_cuda)
#     140         try:
# --> 141             checkpoint = torch.load(filename, lambda storage, loc: storage)
#     142         except BaseException:
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     593
# --> 594     with _open_file_like(f, 'rb') as opened_file:
#     595         if _is_zipfile(opened_file):
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\serialization.py in _open_file_like(name_or_buffer, mode)
#     229     if _is_path(name_or_buffer):
# --> 230         return _open_file(name_or_buffer, mode)
#     231     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\serialization.py in __init__(self, name, mode)
#     210     def __init__(self, name, mode):
# --> 211         super(_open_file, self).__init__(open(name, mode))
#     212
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\karan\\stanza_resources\\hi\\mwt\\default.pt'
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedProcessorError                 Traceback (most recent call last)
# <ipython-input-7-73c981ac649f> in <module>
#      22         doc = CoNLL.conll2doc(filename)
#      23
# ---> 24         nlp = stanza.Pipeline(lang='hi', processors='tokenize,pos,mwt')
#      25         doc1 = nlp(doc)
#      26         print(doc1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\stanza\pipeline\core.py in __init__(self, lang, dir, package, processors, logging_level, verbose, use_gpu, model_dir, **kwargs)
#     156                     if processor_name not in resources[lang]:
#     157                         # user asked for a model which doesn't exist for this language?
# --> 158                         raise UnsupportedProcessorError(processor_name, lang)
#     159                     if not os.path.exists(model_path):
#     160                         model_name, _ = os.path.splitext(model_name)
#
# UnsupportedProcessorError: Processor mwt is not known for language hi.  If you have created your own model, please specify the mwt_model_path parameter when creating the pipeline.

# %% [markdown]
# ## Step 6: Udpos

# %%
import requests
import os
url = "http://lindat.mff.cuni.cz/services/udpipe/api/process"

#giving the path of the directory
path = "E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/Scripts_Ind/"
dirs = os.listdir(path)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_5_misc_new.txt"):
        filename_in = filename
        filename_out = filename_in.replace("_5_misc_new.txt", "_6_udpos_new.txt")
        #print ("in = "+ filename_in)
        #print ("out = "+ filename_out)

        with open(filename_in,'rb') as payload:
            #print(payload.read())
            #var=payload.read()
            #print(var)
            parameters = {
                "data": payload.read(),
                "model": "hindi",
                "input":"conllu",
                "tagger": 1,
            }
            
           #print(payload.read())

            response = requests.post(url, parameters)
            #print(response)
            the_output = response.json()

            with open (filename_out, 'w', encoding= "utf-8") as file:
                file.write(the_output["result"])

# %% [markdown]
# ## Step 7: Udpos_rules

# %%
# The deterministic rules:
#   1. The following are tagged X in one step
#   * disfluency - prefix "d_"
#   * repair - prefix "r_"
#   * hesitation - prefix "h_"
#   * quote - prefix "q_"
#   * code_switching - prefix "c_"
#   * [laughter]
#   * [noise]
#   * [incomprehensible]
#   2. The following tags are modified, unless already tagged X in the previous step:
#   * हाँ > PART
#   * ह्म > PART
#   * [anonymized] >PROPN

import os
import pyconll

#giving the path of the directory
path = "E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/Scripts_Ind/"
dirs = os.listdir(path)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_6_udpos_new.txt"):
        filename_in = filename
        filename_out = filename_in.replace("_6_udpos_new.txt", "_7_udpos_rules_new.txt")
        #print ("in = "+ filename_in)
        #print ("out = "+ filename_out)

        file = pyconll.load_from_file(filename_in)

        for sentence in file:
            for token in sentence:
                misc_item1 = list((token.misc).items())
                #print((token.misc.items()))
                tag = [('Quote', {'Matrix_Tag'}), ('Repair', {'Matrix_Tag'}), ('Disfluency', {'Matrix_Tag'}), 
                       ('Hesitation', {'Matrix_Tag'}),('CodeSwitch', {'Matrix_Tag'}), ('Expletive', {'Matrix_Tag'})]
                for i in tag:
                    if i in misc_item1:
                        token.upos ="X"
                    #print(misc_item1)
                    #print(token.upos)
                #help(token.misc)    
                
                if str(token.form) == "[pause]":
                    token.upos = "X"
                
                if str(token.form) == "[laughter]":
                    token.upos = "X"    
                
                if str(token.form) == "[incomprehensible]":
                    token.upos = "X"

                if str(token.form) == "[noise]":
                    token.upos = "X"

                if str(token.form) == "हाँ":
                    token.upos = "PART"        
            
                if str(token.form) == "ह्म":
                    token.upos = "PART" 

                if str(token.form) == "[anonymized]":
                    token.upos = "PROPN"

                if str(token.lemma) == "है" and str(token.xpos) == "VM":
                    token.upos = "VERB"

                if str(token.lemma) == "था" and str(token.xpos) == "VM":
                    token.upos = "VERB"            

        with open(filename_out, 'w', encoding = 'utf-8') as f:
            file.write(f)

# %% [markdown]
# ## Step 8: Udpos_parse

# %%
import requests
import os
url = "http://lindat.mff.cuni.cz/services/udpipe/api/process"

#giving the path of the directory
path = "E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/Scripts_Ind/"
dirs = os.listdir(path)
#print(dirs)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_7_udpos_rules_new.txt"):
        filename_in = filename
        filename_out = filename_in.replace("_7_udpos_rules_new.txt", "_8_udpos_parse_new.txt")
        #print ("in = "+ filename_in)
        #print ("out = "+ filename_out)

        with open(filename_in,'rb') as payload:
            parameters = {
                "data": payload.read(),
                "model": "hindi",
                "input":"conllu",
                "parser": 1,
            }

            response = requests.post(url, parameters)
            the_output = response.json()

            with open (filename_out, 'w', encoding= "utf-8") as file:
                file.write(the_output["result"])

# %% [markdown]
# ## Dependency Parsing Stanza

# %%
import stanza
from stanza.models.common.doc import Document
from stanza.utils.conll import CoNLL


import requests
import os
#url = "http://lindat.mff.cuni.cz/services/udpipe/api/process"

#giving the path of the directory
path = "E:/Cognitive_Science/Sem_III/HSD621_Masters_Project/syntactic_analysis/"
dirs = os.listdir(path)
#print(dirs)

# for every file in the directory
for file in dirs:
    filename = path+str(file)

    if filename.endswith("_7_udpos_rules_new.txt"):
        filename_in = filename
        #filename_out = filename_in.replace("_7_udpos_rules_Stanza.txt", "_8_udpos_parse_Stanza.txt")
        doc = CoNLL.conll2doc(filename)
        
        
        nlp = stanza.Pipeline(lang='hi', processors='depparse', depparse_pretagged=True)
        #pretagged_doc = Document([[{'id': 1, 'text': 'Test', 'lemma': 'Test', 'upos': 'NOUN', 'xpos': 'NN', 'feats': 'Number=Sing'}, {'id': 2, 'text': 'sentence', 'lemma': 'sentence', 'upos': 'NOUN', 'xpos': 'NN', 'feats': 'Number=Sing'}, {'id': 3, 'text': '.', 'lemma': '.', 'upos': 'PUNCT', 'xpos': '.'}]])
        

        doc1 = nlp(doc)
        print(doc1)
        CoNLL.write_doc2conll(doc1, "output.conllu")
# Out:
# 2021-09-12 19:18:07 INFO: Loading these models for language: hi (Hindi):
# =======================
# | Processor | Package |
# -----------------------
# | depparse  | hdtb    |
# =======================
#
# 2021-09-12 19:18:07 INFO: Use device: cpu
# 2021-09-12 19:18:07 INFO: Loading: depparse
# 2021-09-12 19:18:11 INFO: Done loading processors!
# [
#   [
#     {
#       "id": 1,
#       "text": "ओए",
#       "lemma": "ओए",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 2,
#       "text": "तुम",
#       "lemma": "तुम",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "obj"
#     },
#     {
#       "id": 3,
#       "text": "सुन",
#       "lemma": "सुन",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Number=Plur|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 4,
#       "text": "रहे",
#       "lemma": "रह",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Plur|VerbForm=Part",
#       "head": 3,
#       "deprel": "aux"
#     },
#     {
#       "id": 5,
#       "text": "थे",
#       "lemma": "था",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Gender=Masc|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin",
#       "head": 3,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 6,
#       "text": "ना",
#       "lemma": "ना",
#       "upos": "PART",
#       "xpos": "RP",
#       "head": 3,
#       "deprel": "dep"
#     },
#     {
#       "id": 7,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 3,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "head": 2,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 2,
#       "text": "सुन",
#       "lemma": "सुन",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Number=Sing|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "रहा",
#       "lemma": "रह",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 2,
#       "deprel": "aux"
#     },
#     {
#       "id": 4,
#       "text": "था",
#       "lemma": "था",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin",
#       "head": 2,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 5,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "अब",
#       "lemma": "अब",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|PronType=Prs",
#       "head": 10,
#       "deprel": "obl"
#     },
#     {
#       "id": 2,
#       "text": "क्या",
#       "lemma": "क्या",
#       "upos": "PRON",
#       "xpos": "WQ",
#       "feats": "PronType=Int",
#       "head": 10,
#       "deprel": "obl"
#     },
#     {
#       "id": 3,
#       "text": "अपना",
#       "lemma": "अपना",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|PronType=Prs",
#       "head": 5,
#       "deprel": "nmod"
#     },
#     {
#       "id": 4,
#       "text": "सब",
#       "lemma": "सब",
#       "upos": "PRON",
#       "xpos": "PRPC",
#       "feats": "Case=Nom|Number=Plur|Person=3|PronType=Prs",
#       "head": 5,
#       "deprel": "nmod"
#     },
#     {
#       "id": 5,
#       "text": "रिकॉर्ड",
#       "lemma": "रिकॉर्ड",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 6,
#       "text": "हो",
#       "lemma": "हो",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Voice=Act",
#       "head": 9,
#       "deprel": "nmod"
#     },
#     {
#       "id": 7,
#       "text": "के",
#       "lemma": "का",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post|Case=Acc|Gender=Masc|Number=Sing",
#       "head": 6,
#       "deprel": "mark"
#     },
#     {
#       "id": 8,
#       "text": "हर",
#       "lemma": "हर",
#       "upos": "DET",
#       "xpos": "QF",
#       "feats": "PronType=Ind",
#       "head": 9,
#       "deprel": "det"
#     },
#     {
#       "id": 9,
#       "text": "जगह",
#       "lemma": "जगह",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3",
#       "head": 10,
#       "deprel": "obl"
#     },
#     {
#       "id": 10,
#       "text": "जाएगा",
#       "lemma": "जा",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 11,
#       "text": "क्या",
#       "lemma": "क्या",
#       "upos": "PRON",
#       "xpos": "WQ",
#       "feats": "PronType=Int",
#       "head": 10,
#       "deprel": "obl"
#     },
#     {
#       "id": 12,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 10,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "[laughter]",
#       "lemma": "[laughter]",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 2,
#       "text": "ठीक",
#       "lemma": "ठीक",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "head": 3,
#       "deprel": "obj"
#     },
#     {
#       "id": 3,
#       "text": "है",
#       "lemma": "है",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 4,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 3,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "सीएनएन",
#       "lemma": "सीएनएन",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 2,
#       "text": "न्यूज़",
#       "lemma": "न्यूज़",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "obl"
#     },
#     {
#       "id": 3,
#       "text": "में",
#       "lemma": "में",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 4,
#       "text": "आ",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Number=Plur|Person=3|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 5,
#       "text": "जाएँगे",
#       "lemma": "जा",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Gender=Masc|Mood=Ind|Number=Plur|Person=3|Tense=Fut|VerbForm=Fin",
#       "head": 4,
#       "deprel": "aux"
#     },
#     {
#       "id": 6,
#       "text": "हम",
#       "lemma": "हम",
#       "upos": "DET",
#       "xpos": "DEM",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Dem",
#       "head": 7,
#       "deprel": "det"
#     },
#     {
#       "id": 7,
#       "text": "लोग",
#       "lemma": "लोग",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Plur|Person=3",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 8,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 4,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "[laughter]",
#       "lemma": "[laughter]",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 7,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 2,
#       "text": "यश",
#       "lemma": "यश",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 7,
#       "deprel": "obl"
#     },
#     {
#       "id": 3,
#       "text": "के",
#       "lemma": "के",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 4,
#       "text": "बारे",
#       "lemma": "बारे",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 5,
#       "text": "में",
#       "lemma": "में",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 6,
#       "text": "बात",
#       "lemma": "बात",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3",
#       "head": 7,
#       "deprel": "compound"
#     },
#     {
#       "id": 7,
#       "text": "करो",
#       "lemma": "कर",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Mood=Sub|Number=Sing|Person=2|Polite=Form|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 8,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 7,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "VM",
#       "feats": "Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "[laughter]",
#       "lemma": "[laughter]",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 2,
#       "text": "पब्लिक",
#       "lemma": "पब्लिक",
#       "upos": "NOUN",
#       "xpos": "NNC",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "compound"
#     },
#     {
#       "id": 3,
#       "text": "इन्फ़र्मेशन",
#       "lemma": "इन्फ़र्मेशन",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "xcomp"
#     },
#     {
#       "id": 4,
#       "text": "बनेगा",
#       "lemma": "बन",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 5,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 4,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "सो_आइ_गेस_दैट_दैट्स_बैड_न्यूज़",
#       "lemma": "सो_आइ_गेस_दैट_दैट्स_बैड_न्यूज़",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root",
#       "misc": "CodeSwitch=Matrix_Tag|Disfluency='दैट'|NestedTag=True"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "VM",
#       "feats": "Voice=Act",
#       "head": 2,
#       "deprel": "dep"
#     },
#     {
#       "id": 2,
#       "text": "सीएनएन",
#       "lemma": "सीएनएन",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "में",
#       "lemma": "में",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 4,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "[anonymized]",
#       "lemma": "[anonymized]",
#       "upos": "PROPN",
#       "xpos": "JJ",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "[anonymized]_टॉकिंग_अबाउट_क्यूट_चिक्स_।",
#       "lemma": "[anonymized]_टॉकिंग_अबाउट_क्यूट_चिक्स_।",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root",
#       "misc": "CodeSwitch=Matrix_Tag"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "।",
#       "lemma": "।",
#       "upos": "X",
#       "xpos": "SYM",
#       "head": 0,
#       "deprel": "root",
#       "misc": "CodeSwitch=Matrix_Tag"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "[laughter]",
#       "lemma": "[laughter]",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "नोप",
#       "lemma": "नोप",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "तो",
#       "lemma": "तो",
#       "upos": "PART",
#       "xpos": "RP",
#       "head": 2,
#       "deprel": "dep"
#     },
#     {
#       "id": 2,
#       "text": "एनीवे",
#       "lemma": "एनीवे",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "VM",
#       "head": 3,
#       "deprel": "amod"
#     },
#     {
#       "id": 2,
#       "text": "तो_ये_इस_वक्त_आइ_मीन_अ_ये",
#       "lemma": "तो_ये_इस_वक्त_आइ_मीन_अ_या",
#       "upos": "X",
#       "xpos": "NNPC",
#       "feats": "Case=Nom",
#       "head": 3,
#       "deprel": "compound",
#       "misc": "CodeSwitch='आइ_मीन'|Hesitation='अ'|NestedTag=True|Repair=Matrix_Tag"
#     },
#     {
#       "id": 3,
#       "text": "यश",
#       "lemma": "यश",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 7,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 4,
#       "text": "कहीं",
#       "lemma": "कहीं",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|PronType=Prs",
#       "head": 6,
#       "deprel": "nmod"
#     },
#     {
#       "id": 5,
#       "text": "इंडी",
#       "lemma": "इंडी",
#       "upos": "X",
#       "xpos": "NNPC",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "compound",
#       "misc": "Repair=Matrix_Tag"
#     },
#     {
#       "id": 6,
#       "text": "यूएसए",
#       "lemma": "यूएसए",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 7,
#       "deprel": "obl"
#     },
#     {
#       "id": 7,
#       "text": "आ",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Number=Sing|Person=3|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 8,
#       "text": "रहा",
#       "lemma": "रह",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 7,
#       "deprel": "aux"
#     },
#     {
#       "id": 9,
#       "text": "है",
#       "lemma": "है",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 7,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 10,
#       "text": "कि",
#       "lemma": "कि",
#       "upos": "SCONJ",
#       "xpos": "CC",
#       "head": 12,
#       "deprel": "mark"
#     },
#     {
#       "id": 11,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 12,
#       "deprel": "advmod"
#     },
#     {
#       "id": 12,
#       "text": "आ",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Number=Sing|Person=3|Voice=Act",
#       "head": 7,
#       "deprel": "obj"
#     },
#     {
#       "id": 13,
#       "text": "रहा",
#       "lemma": "रह",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 12,
#       "deprel": "aux"
#     },
#     {
#       "id": 14,
#       "text": "है",
#       "lemma": "है",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 12,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 15,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 7,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "VM",
#       "feats": "Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|PronType=Prs",
#       "head": 2,
#       "deprel": "obl"
#     },
#     {
#       "id": 2,
#       "text": "आ",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Number=Sing|Person=3|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "रहा",
#       "lemma": "रह",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 2,
#       "deprel": "aux"
#     },
#     {
#       "id": 4,
#       "text": "है",
#       "lemma": "है",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 2,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 5,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हील",
#       "lemma": "हील",
#       "upos": "X",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 5,
#       "deprel": "nsubj",
#       "misc": "CodeSwitch='हील'|NestedTag=True|Repair=Matrix_Tag"
#     },
#     {
#       "id": 2,
#       "text": "नवम्बर",
#       "lemma": "नवम्बर",
#       "upos": "PROPN",
#       "xpos": "NNPC",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "compound"
#     },
#     {
#       "id": 3,
#       "text": "26",
#       "lemma": "26",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Acc|Number=Sing|Person=3",
#       "head": 5,
#       "deprel": "obl"
#     },
#     {
#       "id": 4,
#       "text": "को",
#       "lemma": "को",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 3,
#       "deprel": "case"
#     },
#     {
#       "id": 5,
#       "text": "आएगा",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 6,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 5,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "[incomprehensible]",
#       "lemma": "[incomprehensible]",
#       "upos": "X",
#       "xpos": "RB",
#       "head": 2,
#       "deprel": "obl"
#     },
#     {
#       "id": 2,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 4,
#       "deprel": "advmod"
#     },
#     {
#       "id": 2,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 4,
#       "deprel": "advmod"
#     },
#     {
#       "id": 3,
#       "text": "वो",
#       "lemma": "वह",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=3|Polite=Form|PronType=Prs",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 4,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 5,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 4,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "अम",
#       "lemma": "अम",
#       "upos": "X",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "head": 2,
#       "deprel": "compound",
#       "misc": "Hesitation=Matrix_Tag"
#     },
#     {
#       "id": 2,
#       "text": "कॉन्फ़्रेन्स",
#       "lemma": "कॉन्फ़्रेन्स",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 5,
#       "deprel": "nmod"
#     },
#     {
#       "id": 3,
#       "text": "के",
#       "lemma": "के",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 4,
#       "text": "लिए",
#       "lemma": "लिए",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 5,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 6,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 5,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "जॉब",
#       "lemma": "जॉब",
#       "upos": "PROPN",
#       "xpos": "NNPC",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 2,
#       "deprel": "compound"
#     },
#     {
#       "id": 2,
#       "text": "वॉब",
#       "lemma": "वॉब",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "जॉब",
#       "lemma": "जॉब",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "nmod"
#     },
#     {
#       "id": 2,
#       "text": "के",
#       "lemma": "के",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 1,
#       "deprel": "case"
#     },
#     {
#       "id": 3,
#       "text": "लिए",
#       "lemma": "लिए",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 1,
#       "deprel": "case"
#     },
#     {
#       "id": 4,
#       "text": "तो",
#       "lemma": "तो",
#       "upos": "PART",
#       "xpos": "RP",
#       "head": 1,
#       "deprel": "dep"
#     },
#     {
#       "id": 5,
#       "text": "पता",
#       "lemma": "पता",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "compound"
#     },
#     {
#       "id": 6,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 7,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 6,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "जॉब",
#       "lemma": "जॉब",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "obj"
#     },
#     {
#       "id": 2,
#       "text": "तो",
#       "lemma": "तो",
#       "upos": "PART",
#       "xpos": "RP",
#       "head": 1,
#       "deprel": "dep"
#     },
#     {
#       "id": 3,
#       "text": "आ",
#       "lemma": "आ",
#       "upos": "X",
#       "xpos": "VM",
#       "head": 4,
#       "deprel": "advcl",
#       "misc": "Hesitation=Matrix_Tag"
#     },
#     {
#       "id": 4,
#       "text": "मिला",
#       "lemma": "मिल",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 5,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 4,
#       "deprel": "advmod"
#     },
#     {
#       "id": 6,
#       "text": "ना",
#       "lemma": "ना",
#       "upos": "PART",
#       "xpos": "RP",
#       "head": 4,
#       "deprel": "dep"
#     },
#     {
#       "id": 7,
#       "text": "उस",
#       "lemma": "वह",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Number=Sing|Person=3|PronType=Prs",
#       "head": 4,
#       "deprel": "obl"
#     },
#     {
#       "id": 8,
#       "text": "को",
#       "lemma": "को",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 7,
#       "deprel": "case"
#     },
#     {
#       "id": 9,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 4,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "आ_के",
#       "lemma": "आ_के",
#       "upos": "X",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 7,
#       "deprel": "nsubj",
#       "misc": "Repair=Matrix_Tag"
#     },
#     {
#       "id": 2,
#       "text": "यहाँ",
#       "lemma": "यहाँ",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|PronType=Prs",
#       "head": 3,
#       "deprel": "obl"
#     },
#     {
#       "id": 3,
#       "text": "आने",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Case=Acc|Number=Sing|Person=3|VerbForm=Inf",
#       "head": 7,
#       "deprel": "obl"
#     },
#     {
#       "id": 4,
#       "text": "के",
#       "lemma": "के",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 3,
#       "deprel": "mark"
#     },
#     {
#       "id": 5,
#       "text": "बाद",
#       "lemma": "बाद",
#       "upos": "ADV",
#       "xpos": "NST",
#       "feats": "AdpType=Post|Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "mark"
#     },
#     {
#       "id": 6,
#       "text": "ट्राए",
#       "lemma": "ट्राए",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 7,
#       "deprel": "compound"
#     },
#     {
#       "id": 7,
#       "text": "करेगा",
#       "lemma": "कर",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 8,
#       "text": "फ़िर",
#       "lemma": "फ़िर",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 7,
#       "deprel": "advmod"
#     },
#     {
#       "id": 9,
#       "text": "से",
#       "lemma": "से",
#       "upos": "PART",
#       "xpos": "RP",
#       "head": 7,
#       "deprel": "dep"
#     },
#     {
#       "id": 10,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 7,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "यहाँ",
#       "lemma": "यहाँ",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|PronType=Prs",
#       "head": 3,
#       "deprel": "obl"
#     },
#     {
#       "id": 2,
#       "text": "पर",
#       "lemma": "पर",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 1,
#       "deprel": "case"
#     },
#     {
#       "id": 3,
#       "text": "घूमने",
#       "lemma": "घूम",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Case=Acc|VerbForm=Inf",
#       "head": 6,
#       "deprel": "advcl"
#     },
#     {
#       "id": 4,
#       "text": "के",
#       "lemma": "के",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 3,
#       "deprel": "mark"
#     },
#     {
#       "id": 5,
#       "text": "लिए",
#       "lemma": "लिए",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 3,
#       "deprel": "mark"
#     },
#     {
#       "id": 6,
#       "text": "आ",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Number=Sing|Person=3|Voice=Act",
#       "head": 9,
#       "deprel": "acl:relcl"
#     },
#     {
#       "id": 7,
#       "text": "रहा",
#       "lemma": "रह",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 6,
#       "deprel": "aux"
#     },
#     {
#       "id": 8,
#       "text": "है",
#       "lemma": "है",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 6,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 9,
#       "text": "वो",
#       "lemma": "वह",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=3|PronType=Prs",
#       "head": 13,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 10,
#       "text": "इस",
#       "lemma": "यह",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Number=Sing|Person=3|PronType=Prs",
#       "head": 13,
#       "deprel": "obl"
#     },
#     {
#       "id": 11,
#       "text": "के",
#       "lemma": "के",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 10,
#       "deprel": "case"
#     },
#     {
#       "id": 12,
#       "text": "साथ",
#       "lemma": "साथ",
#       "upos": "ADP",
#       "xpos": "NST",
#       "feats": "AdpType=Post|Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 10,
#       "deprel": "case"
#     },
#     {
#       "id": 13,
#       "text": "आएगा",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 14,
#       "text": "अम_अह",
#       "lemma": "अम_अह",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 13,
#       "deprel": "nsubj",
#       "misc": "Hesitation=Matrix_Tag"
#     },
#     {
#       "id": 15,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 13,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "अपने",
#       "lemma": "अपना",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Gender=Masc|PronType=Prs",
#       "head": 2,
#       "deprel": "nmod"
#     },
#     {
#       "id": 2,
#       "text": "बीवी",
#       "lemma": "बीवी",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 5,
#       "deprel": "obl"
#     },
#     {
#       "id": 3,
#       "text": "के",
#       "lemma": "के",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 4,
#       "text": "साथ",
#       "lemma": "साथ",
#       "upos": "ADP",
#       "xpos": "NST",
#       "feats": "AdpType=Post|Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 5,
#       "text": "आएगा",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 6,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 5,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "नीलिमा",
#       "lemma": "नीलिमा",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "इस",
#       "lemma": "यह",
#       "upos": "DET",
#       "xpos": "DEM",
#       "feats": "Case=Acc|Number=Sing|Person=3|PronType=Dem",
#       "head": 2,
#       "deprel": "det"
#     },
#     {
#       "id": 2,
#       "text": "बार",
#       "lemma": "बार",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#       "head": 10,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 2,
#       "text": "इस",
#       "lemma": "यह",
#       "upos": "DET",
#       "xpos": "DEM",
#       "feats": "Case=Acc|Number=Sing|Person=3|PronType=Dem",
#       "head": 3,
#       "deprel": "det"
#     },
#     {
#       "id": 3,
#       "text": "बार",
#       "lemma": "बार",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3",
#       "head": 10,
#       "deprel": "obl"
#     },
#     {
#       "id": 4,
#       "text": "बीवी",
#       "lemma": "बीवी",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing|Person=3",
#       "head": 10,
#       "deprel": "obl"
#     },
#     {
#       "id": 5,
#       "text": "के",
#       "lemma": "के",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 4,
#       "deprel": "case"
#     },
#     {
#       "id": 6,
#       "text": "साथ",
#       "lemma": "साथ",
#       "upos": "ADP",
#       "xpos": "NST",
#       "feats": "AdpType=Post|Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "case"
#     },
#     {
#       "id": 7,
#       "text": "यहाँ",
#       "lemma": "यहाँ",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|PronType=Prs",
#       "head": 9,
#       "deprel": "obl"
#     },
#     {
#       "id": 8,
#       "text": "पर",
#       "lemma": "पर",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 7,
#       "deprel": "case"
#     },
#     {
#       "id": 9,
#       "text": "थोड़ा",
#       "lemma": "थोड़ा",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Number=Sing",
#       "head": 10,
#       "deprel": "advcl"
#     },
#     {
#       "id": 10,
#       "text": "घूमेगा",
#       "lemma": "घूम",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 11,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 10,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "ग्रैंड",
#       "lemma": "ग्रैंड",
#       "upos": "NOUN",
#       "xpos": "NNC",
#       "feats": "Case=Nom",
#       "head": 2,
#       "deprel": "compound"
#     },
#     {
#       "id": 2,
#       "text": "कैनियन",
#       "lemma": "कैनियन",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 3,
#       "text": "सब",
#       "lemma": "सब",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=3|PronType=Prs",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 4,
#       "text": "घूमेगा",
#       "lemma": "घूम",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 5,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 4,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "बोल",
#       "lemma": "बोल",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Number=Sing|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "रहा",
#       "lemma": "रह",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 1,
#       "deprel": "aux"
#     },
#     {
#       "id": 3,
#       "text": "कि",
#       "lemma": "कि",
#       "upos": "SCONJ",
#       "xpos": "CC",
#       "head": 9,
#       "deprel": "mark"
#     },
#     {
#       "id": 4,
#       "text": "यूएस",
#       "lemma": "यूएस",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 5,
#       "text": "पूरा",
#       "lemma": "पूरा",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing",
#       "head": 6,
#       "deprel": "amod"
#     },
#     {
#       "id": 6,
#       "text": "घूम",
#       "lemma": "घूम",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 9,
#       "deprel": "nmod"
#     },
#     {
#       "id": 7,
#       "text": "के",
#       "lemma": "का",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post|Case=Acc|Gender=Masc|Number=Sing",
#       "head": 6,
#       "deprel": "case"
#     },
#     {
#       "id": 8,
#       "text": "जाएगा",
#       "lemma": "जा",
#       "upos": "AUX",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 1,
#       "deprel": "obj"
#     },
#     {
#       "id": 9,
#       "text": "वापस",
#       "lemma": "वापस",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "head": 1,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 10,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "[incomprehensible]",
#       "lemma": "[incomprehensible]",
#       "upos": "X",
#       "xpos": "JJ",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "इस",
#       "lemma": "यह",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc|Number=Sing|Person=3|PronType=Prs",
#       "head": 3,
#       "deprel": "nmod"
#     },
#     {
#       "id": 2,
#       "text": "का",
#       "lemma": "का",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post|Case=Nom|Gender=Masc|Number=Sing",
#       "head": 1,
#       "deprel": "case"
#     },
#     {
#       "id": 3,
#       "text": "मतलब",
#       "lemma": "मतलब",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 7,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 4,
#       "text": "लंबी",
#       "lemma": "लंबा",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing",
#       "head": 5,
#       "deprel": "amod"
#     },
#     {
#       "id": 5,
#       "text": "छुट्टी",
#       "lemma": "छुट्टी",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing|Person=3",
#       "head": 7,
#       "deprel": "obl"
#     },
#     {
#       "id": 6,
#       "text": "पर",
#       "lemma": "पर",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 5,
#       "deprel": "case"
#     },
#     {
#       "id": 7,
#       "text": "आ",
#       "lemma": "आ",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Number=Sing|Person=3|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 8,
#       "text": "रहा",
#       "lemma": "रह",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 7,
#       "deprel": "aux"
#     },
#     {
#       "id": 9,
#       "text": "है",
#       "lemma": "है",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 7,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 10,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 7,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "dep"
#     },
#     {
#       "id": 2,
#       "text": "15",
#       "lemma": "15",
#       "upos": "NUM",
#       "xpos": "QCC",
#       "feats": "NumType=Card",
#       "head": 3,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 3,
#       "text": "20",
#       "lemma": "20",
#       "upos": "NUM",
#       "xpos": "QC",
#       "feats": "NumType=Card",
#       "head": 4,
#       "deprel": "nummod"
#     },
#     {
#       "id": 4,
#       "text": "दिन",
#       "lemma": "दिन",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "nmod"
#     },
#     {
#       "id": 5,
#       "text": "की",
#       "lemma": "का",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post|Case=Acc|Gender=Fem|Number=Sing",
#       "head": 4,
#       "deprel": "case"
#     },
#     {
#       "id": 6,
#       "text": "छुट्टी",
#       "lemma": "छुट्टी",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Fem|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 7,
#       "text": "पर",
#       "lemma": "पर",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 6,
#       "deprel": "case"
#     },
#     {
#       "id": 8,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 6,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "पर",
#       "lemma": "पर",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 3,
#       "deprel": "cc"
#     },
#     {
#       "id": 2,
#       "text": "यूएस",
#       "lemma": "यूएस",
#       "upos": "PROPN",
#       "xpos": "NNPC",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "compound"
#     },
#     {
#       "id": 3,
#       "text": "सब",
#       "lemma": "सब",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 4,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 3,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "आइ_मीन",
#       "lemma": "आइ_मीन",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "nsubj",
#       "misc": "CodeSwitch=Matrix_Tag"
#     },
#     {
#       "id": 2,
#       "text": "तब",
#       "lemma": "तब",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|PronType=Prs",
#       "head": 6,
#       "deprel": "obl"
#     },
#     {
#       "id": 3,
#       "text": "तो",
#       "lemma": "तो",
#       "upos": "PART",
#       "xpos": "RP",
#       "head": 2,
#       "deprel": "dep"
#     },
#     {
#       "id": 4,
#       "text": "इतना",
#       "lemma": "इतना",
#       "upos": "DET",
#       "xpos": "QF",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing",
#       "head": 5,
#       "deprel": "det"
#     },
#     {
#       "id": 5,
#       "text": "ठंड",
#       "lemma": "ठंड",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "compound"
#     },
#     {
#       "id": 6,
#       "text": "होगा",
#       "lemma": "हो",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 7,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 6,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "आयोवा",
#       "lemma": "आयोवा",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 2,
#       "deprel": "obl"
#     },
#     {
#       "id": 2,
#       "text": "जा",
#       "lemma": "जा",
#       "upos": "VERB",
#       "xpos": "VM",
#       "head": 5,
#       "deprel": "advcl"
#     },
#     {
#       "id": 3,
#       "text": "कर",
#       "lemma": "कर",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "head": 2,
#       "deprel": "aux"
#     },
#     {
#       "id": 4,
#       "text": "क्या",
#       "lemma": "क्या",
#       "upos": "PRON",
#       "xpos": "WQ",
#       "feats": "PronType=Int",
#       "head": 5,
#       "deprel": "obl"
#     },
#     {
#       "id": 5,
#       "text": "करेगा",
#       "lemma": "कर",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 6,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 5,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "अबे",
#       "lemma": "अबे",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|PronType=Prs",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "लेकिन",
#       "lemma": "लेकिन",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 5,
#       "deprel": "cc"
#     },
#     {
#       "id": 3,
#       "text": "नवम्बर",
#       "lemma": "नवम्बर",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 1,
#       "deprel": "conj"
#     },
#     {
#       "id": 4,
# ...
#   ],
#   [
#     {
#       "id": 1,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "आइआइटी",
#       "lemma": "आइआइटी",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 2,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 2,
#       "text": "कानपुर",
#       "lemma": "कानपुर",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "में",
#       "lemma": "में",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 4,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "दे_गैट_बेटर_स्कॉल्स_नाउ",
#       "lemma": "दे_गैट_बेटर_स्कॉल्स_नाउ",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root",
#       "misc": "CodeSwitch=Matrix_Tag"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 2,
#       "deprel": "obl"
#     },
#     {
#       "id": 2,
#       "text": "हाँ",
#       "lemma": "हाँ",
#       "upos": "PART",
#       "xpos": "VM",
#       "feats": "Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "हमारा",
#       "lemma": "हम",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Acc,Gen|Gender=Masc|Number=Plur|Person=1|Poss=Yes|PronType=Prs",
#       "head": 2,
#       "deprel": "nmod"
#     },
#     {
#       "id": 2,
#       "text": "समय",
#       "lemma": "समय",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "obl"
#     },
#     {
#       "id": 3,
#       "text": "में",
#       "lemma": "में",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 4,
#       "text": "बर्क्ली",
#       "lemma": "बर्क्ली",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3",
#       "head": 6,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 5,
#       "text": "कोई",
#       "lemma": "कोई",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=3|PronType=Prs",
#       "head": 6,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 6,
#       "text": "गया",
#       "lemma": "जा",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 7,
#       "text": "ही",
#       "lemma": "ही",
#       "upos": "PART",
#       "xpos": "RP",
#       "head": 6,
#       "deprel": "dep"
#     },
#     {
#       "id": 8,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 6,
#       "deprel": "advmod"
#     },
#     {
#       "id": 9,
#       "text": "था",
#       "lemma": "था",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin",
#       "head": 6,
#       "deprel": "aux"
#     },
#     {
#       "id": 10,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 6,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "QC",
#       "feats": "NumType=Card",
#       "head": 2,
#       "deprel": "nummod"
#     },
#     {
#       "id": 2,
#       "text": "बंदे",
#       "lemma": "बंदा",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 3,
#       "text": "को",
#       "lemma": "को",
#       "upos": "ADP",
#       "xpos": "PSP",
#       "feats": "AdpType=Post",
#       "head": 2,
#       "deprel": "case"
#     },
#     {
#       "id": 4,
#       "text": "मिली",
#       "lemma": "मिल",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Aspect=Perf|Gender=Fem|Number=Sing|VerbForm=Part|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 5,
#       "text": "थी",
#       "lemma": "था",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin",
#       "head": 4,
#       "deprel": "aux"
#     },
#     {
#       "id": 6,
#       "text": "स्टैनफोर्ड",
#       "lemma": "स्टैनफोर्ड",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 7,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 4,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 2,
#       "deprel": "dep"
#     },
#     {
#       "id": 2,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "ए_अह",
#       "lemma": "ए_अह",
#       "upos": "X",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 0,
#       "deprel": "root",
#       "misc": "Hesitation=Matrix_Tag"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "कोई",
#       "lemma": "कोई",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=3|PronType=Prs",
#       "head": 2,
#       "deprel": "punct"
#     },
#     {
#       "id": 2,
#       "text": "अरबाना",
#       "lemma": "अरबाना",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 3,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 4,
#       "deprel": "advmod"
#     },
#     {
#       "id": 4,
#       "text": "गया",
#       "lemma": "जा",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 5,
#       "text": "था",
#       "lemma": "था",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin",
#       "head": 4,
#       "deprel": "aux"
#     },
#     {
#       "id": 6,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 4,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "कुछ",
#       "lemma": "कुछ",
#       "upos": "DET",
#       "xpos": "QF",
#       "feats": "PronType=Ind",
#       "head": 2,
#       "deprel": "det"
#     },
#     {
#       "id": 2,
#       "text": "लोग",
#       "lemma": "लोग",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Plur|Person=3",
#       "head": 3,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 3,
#       "text": "गए",
#       "lemma": "जा",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Plur|VerbForm=Part|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 4,
#       "text": "थे",
#       "lemma": "था",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Gender=Masc|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin",
#       "head": 3,
#       "deprel": "aux"
#     },
#     {
#       "id": 5,
#       "text": "1_कॉर्नेल",
#       "lemma": "1_कॉर्नेल",
#       "upos": "X",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 10,
#       "deprel": "nsubj",
#       "misc": "Repair=Matrix_Tag"
#     },
#     {
#       "id": 6,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 10,
#       "deprel": "advmod"
#     },
#     {
#       "id": 7,
#       "text": "कॉर्नेल",
#       "lemma": "कॉर्नेल",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 10,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 8,
#       "text": "भी",
#       "lemma": "भी",
#       "upos": "PART",
#       "xpos": "RP",
#       "head": 7,
#       "deprel": "dep"
#     },
#     {
#       "id": 9,
#       "text": "नहीं",
#       "lemma": "नहीं",
#       "upos": "PART",
#       "xpos": "NEG",
#       "feats": "Polarity=Neg|PronType=Neg",
#       "head": 10,
#       "deprel": "advmod"
#     },
#     {
#       "id": 10,
#       "text": "गया",
#       "lemma": "जा",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Act",
#       "head": 3,
#       "deprel": "advcl"
#     },
#     {
#       "id": 11,
#       "text": "था",
#       "lemma": "था",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin",
#       "head": 10,
#       "deprel": "aux"
#     },
#     {
#       "id": 12,
#       "text": "कोई",
#       "lemma": "कोई",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=3|PronType=Prs",
#       "head": 10,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 13,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 10,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "यूपेन",
#       "lemma": "यूपेन",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 4,
#       "deprel": "nsubj"
#     },
#     {
#       "id": 2,
#       "text": "टाइप",
#       "lemma": "टाइप",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "obj"
#     },
#     {
#       "id": 3,
#       "text": "जगह",
#       "lemma": "जगह",
#       "upos": "VERB",
#       "xpos": "VM",
#       "head": 4,
#       "deprel": "advcl"
#     },
#     {
#       "id": 4,
#       "text": "गए",
#       "lemma": "जा",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|Person=3|Polite=Form|VerbForm=Part|Voice=Act",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 5,
#       "text": "थे",
#       "lemma": "था",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Gender=Masc|Mood=Ind|Number=Sing|Person=3|Polite=Form|Tense=Past|VerbForm=Fin",
#       "head": 4,
#       "deprel": "aux"
#     },
#     {
#       "id": 6,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 4,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "युपेन",
#       "lemma": "युपेन",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "nsubj:pass"
#     },
#     {
#       "id": 2,
#       "text": "कोई",
#       "lemma": "कोई",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Sing|Person=3|PronType=Prs",
#       "head": 3,
#       "deprel": "obj"
#     },
#     {
#       "id": 3,
#       "text": "चला",
#       "lemma": "चल",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 4,
#       "text": "गया",
#       "lemma": "जा",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 3,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 5,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 3,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "या",
#       "lemma": "या",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 3,
#       "deprel": "cc"
#     },
#     {
#       "id": 2,
#       "text": "मैडिसन",
#       "lemma": "मैडिसन",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3",
#       "head": 3,
#       "deprel": "obl"
#     },
#     {
#       "id": 3,
#       "text": "चला",
#       "lemma": "चल",
#       "upos": "VERB",
#       "xpos": "VM",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 4,
#       "text": "गया",
#       "lemma": "जा",
#       "upos": "AUX",
#       "xpos": "VAUX",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|VerbForm=Part",
#       "head": 3,
#       "deprel": "aux:pass"
#     },
#     {
#       "id": 5,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 3,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 2,
#       "deprel": "dep"
#     },
#     {
#       "id": 2,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 3,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 2,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "ह्म",
#       "lemma": "ह्म",
#       "upos": "PART",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Number=Plur|Person=1|PronType=Prs",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "और",
#       "lemma": "और",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 0,
#       "deprel": "root"
#     },
#     {
#       "id": 2,
#       "text": "।",
#       "lemma": "।",
#       "upos": "PUNCT",
#       "xpos": "SYM",
#       "head": 1,
#       "deprel": "punct"
#     }
#   ]
# ]

# %%
from stanza.utils.conll import CoNLL
doc = CoNLL.conll2doc("extern_data/ud2/ud-treebanks-v2.7/UD_Italian-ISDT/it_isdt-ud-train.conllu")
